# %% [markdown]
# # **Task A – Data Transformation**

# %% [markdown]
# # Task A(a) - Load the dataset into a DataFrame.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('supply_chain_data.csv')

# %% [markdown]
# # Task A(b) - Show the first few rows of the loaded dataset.

# %%
# Show the first few rows
print(df.head())
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %% [markdown]
# # Task A(c) - Apply three operations to handle missing values in the dataset.

# %%
# Identify numeric and non-numeric columns
numeric_cols = df.select_dtypes(include='number').columns
non_numeric_cols = df.select_dtypes(exclude='number').columns

# Operation 1: Fill missing values with a specific value (e.g., 0) for numeric columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# Operation 2: Drop rows with missing values (Note: This will drop rows where any column has missing values)
df.dropna(inplace=True)

# Operation 3: Fill missing values with the mean of the column for numeric columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Verify missing values handled
print(df.isnull().sum())
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
# Sort the dataframe by the 'Price' column
df_sorted = df.sort_values(by='Price')
print(df_sorted.head())

# Filter transactions where the 'Number of products sold' is greater than 500
filtered_df = df[df['Number of products sold'] > 500]
print(filtered_df.head())

# Create a new column 'Revenue per Product' derived from 'Revenue generated' / 'Number of products sold'
df['Revenue per Product'] = df['Revenue generated'] / df['Number of products sold']
print(df.head())

# Aggregate data based on the 'Product type' column
aggregated_df = df.groupby('Product type').agg({
    'Revenue generated': 'sum',
    'Number of products sold': 'sum'
}).reset_index()
print(aggregated_df)
# Out:
#    Product type    SKU     Price  Availability  Number of products sold  \
# 5      haircare   SKU5  1.699976            87                      147
# 28    cosmetics  SKU28  2.397275            12                      394
# 94    cosmetics  SKU94  3.037689            97                      987
# 74     haircare  SKU74  3.170011            64                      904
# 97     haircare  SKU97  3.526111            56                       62
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 5         2828.348746            Non-binary            90          27
# 28        6117.324615                Female            48          15
# 94        7888.356547               Unknown            77          26
# 74        5709.945296                Female            41           6
# 97        4370.916580                  Male            46          19
#
#     Order quantities  ...   Location Lead time  Production volumes  \
# 5                 66  ...  Bangalore        10                 104
# 28                24  ...     Mumbai        13                 171
# 94                72  ...      Delhi        12                 908
# 74                 1  ...      Delhi         1                 919
# 97                 4  ...     Mumbai        10                 535
#
#    Manufacturing lead time Manufacturing costs  Inspection results  \
# 5                       17           56.766476                Fail
# 28                       7           59.429382                Fail
# 94                      14           60.387379                Pass
# 74                       9           80.580852                Fail
# 97                      13           65.765156                Fail
#
#     Defect rates  Transportation modes   Routes       Costs
# 5       2.779194                  Road  Route A  235.461237
# 28      0.815757                   Air  Route A  123.437028
# 94      1.463607                  Rail  Route B  846.665257
# 74      0.396613                  Rail  Route A  341.552657
# 97      3.376238                  Road  Route A  540.132423
#
# [5 rows x 24 columns]
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 4      skincare   SKU4   4.805496            26                      871
# 9      skincare   SKU9  64.015733            35                      980
# 10     skincare  SKU10  15.707796            11                      996
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 0         8661.996792            Non-binary            58           7
# 1         7460.900065                Female            53          30
# 4         2686.505152            Non-binary             5           3
# 9         4971.145988               Unknown            14          27
# 10        2330.965802            Non-binary            51          13
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# 0                 96  ...    Mumbai        29                 215
# 1                 37  ...    Mumbai        23                 517
# 4                 56  ...     Delhi         5                 414
# 9                 83  ...   Chennai        29                 963
# 10                80  ...   Kolkata        18                 830
#
#    Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                       29           46.279879             Pending
# 1                       30           33.616769             Pending
# 4                        3           92.065161                Fail
# 9                       23           47.957602             Pending
# 10                       5           96.527353                Pass
#
#     Defect rates  Transportation modes   Routes       Costs
# 0       0.226410                  Road  Route B  187.752075
# 1       4.854068                  Road  Route B  503.065579
# 4       3.145580                   Air  Route A  923.440632
# 9       3.844614                  Rail  Route B  995.929461
# 10      1.727314                  Road  Route B  806.103178
#
# [5 rows x 24 columns]
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Lead time Production volumes  \
# 0                96  ...         29                215
# 1                37  ...         23                517
# 2                88  ...         12                971
# 3                59  ...         24                937
# 4                56  ...          5                414
#
#    Manufacturing lead time Manufacturing costs Inspection results  \
# 0                       29           46.279879            Pending
# 1                       30           33.616769            Pending
# 2                       27           30.688019            Pending
# 3                       18           35.624741               Fail
# 4                        3           92.065161               Fail
#
#    Defect rates  Transportation modes   Routes       Costs Revenue per Product
# 0      0.226410                  Road  Route B  187.752075           10.800495
# 1      4.854068                  Road  Route B  503.065579           10.137092
# 2      4.580593                   Air  Route C  141.920282         1197.218703
# 3      4.746649                  Rail  Route A  254.776159           93.576342
# 4      3.145580                   Air  Route A  923.440632            3.084392
#
# [5 rows x 25 columns]
#   Product type  Revenue generated  Number of products sold
# 0    cosmetics      161521.265999                    11757
# 1     haircare      174455.390605                    13611
# 2     skincare      241628.162133                    20731

# %% [markdown]
# # Task A(d) - Choose a column and perform the sorting technique.

# %%
# Sort the dataframe by the 'Price' column
df_sorted = df.sort_values(by='Price')
print(df_sorted.head())
# Out:
#    Product type    SKU     Price  Availability  Number of products sold  \
# 5      haircare   SKU5  1.699976            87                      147
# 28    cosmetics  SKU28  2.397275            12                      394
# 94    cosmetics  SKU94  3.037689            97                      987
# 74     haircare  SKU74  3.170011            64                      904
# 97     haircare  SKU97  3.526111            56                       62
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 5         2828.348746            Non-binary            90          27
# 28        6117.324615                Female            48          15
# 94        7888.356547               Unknown            77          26
# 74        5709.945296                Female            41           6
# 97        4370.916580                  Male            46          19
#
#     Order quantities  ...  Lead time Production volumes  \
# 5                 66  ...         10                104
# 28                24  ...         13                171
# 94                72  ...         12                908
# 74                 1  ...          1                919
# 97                 4  ...         10                535
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 5                        17           56.766476               Fail
# 28                        7           59.429382               Fail
# 94                       14           60.387379               Pass
# 74                        9           80.580852               Fail
# 97                       13           65.765156               Fail
#
#     Defect rates  Transportation modes   Routes       Costs  \
# 5       2.779194                  Road  Route A  235.461237
# 28      0.815757                   Air  Route A  123.437028
# 94      1.463607                  Rail  Route B  846.665257
# 74      0.396613                  Rail  Route A  341.552657
# 97      3.376238                  Road  Route A  540.132423
#
#    Revenue per Product
# 5            19.240468
# 28           15.526205
# 94            7.992256
# 74            6.316311
# 97           70.498655
#
# [5 rows x 25 columns]

# %% [markdown]
# # Task A(e) - Define a condition to filter transactions from the dataset.

# %%
# Filter transactions where the 'Number of products sold' is greater than 500
filtered_df = df[df['Number of products sold'] > 500]
print(filtered_df.head())
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 0      haircare   SKU0  69.808006            55                      802
# 1      skincare   SKU1  14.843523            95                      736
# 4      skincare   SKU4   4.805496            26                      871
# 9      skincare   SKU9  64.015733            35                      980
# 10     skincare  SKU10  15.707796            11                      996
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 0         8661.996792            Non-binary            58           7
# 1         7460.900065                Female            53          30
# 4         2686.505152            Non-binary             5           3
# 9         4971.145988               Unknown            14          27
# 10        2330.965802            Non-binary            51          13
#
#     Order quantities  ...  Lead time Production volumes  \
# 0                 96  ...         29                215
# 1                 37  ...         23                517
# 4                 56  ...          5                414
# 9                 83  ...         29                963
# 10                80  ...         18                830
#
#     Manufacturing lead time Manufacturing costs Inspection results  \
# 0                        29           46.279879            Pending
# 1                        30           33.616769            Pending
# 4                         3           92.065161               Fail
# 9                        23           47.957602            Pending
# 10                        5           96.527353               Pass
#
#     Defect rates  Transportation modes   Routes       Costs  \
# 0       0.226410                  Road  Route B  187.752075
# 1       4.854068                  Road  Route B  503.065579
# 4       3.145580                   Air  Route A  923.440632
# 9       3.844614                  Rail  Route B  995.929461
# 10      1.727314                  Road  Route B  806.103178
#
#    Revenue per Product
# 0            10.800495
# 1            10.137092
# 4             3.084392
# 9             5.072598
# 10            2.340327
#
# [5 rows x 25 columns]

# %% [markdown]
# # Task A(f) - Create a new column to derive additional information.

# %%
# Create a new column 'Revenue per Product' derived from 'Revenue generated' / 'Number of products sold'
df['Revenue per Product'] = df['Revenue generated'] / df['Number of products sold']
print(df.head())
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Lead time Production volumes  \
# 0                96  ...         29                215
# 1                37  ...         23                517
# 2                88  ...         12                971
# 3                59  ...         24                937
# 4                56  ...          5                414
#
#    Manufacturing lead time Manufacturing costs Inspection results  \
# 0                       29           46.279879            Pending
# 1                       30           33.616769            Pending
# 2                       27           30.688019            Pending
# 3                       18           35.624741               Fail
# 4                        3           92.065161               Fail
#
#    Defect rates  Transportation modes   Routes       Costs Revenue per Product
# 0      0.226410                  Road  Route B  187.752075           10.800495
# 1      4.854068                  Road  Route B  503.065579           10.137092
# 2      4.580593                   Air  Route C  141.920282         1197.218703
# 3      4.746649                  Rail  Route A  254.776159           93.576342
# 4      3.145580                   Air  Route A  923.440632            3.084392
#
# [5 rows x 25 columns]

# %% [markdown]
# # Task A(g) - Choose the categorical column and aggregate data based on it.

# %%
# Aggregate data based on the 'Product type' column
aggregated_df = df.groupby('Product type').agg({
    'Revenue generated': 'sum',
    'Number of products sold': 'sum'
}).reset_index()
print(aggregated_df)
# Out:
#   Product type  Revenue generated  Number of products sold
# 0    cosmetics      161521.265999                    11757
# 1     haircare      174455.390605                    13611
# 2     skincare      241628.162133                    20731

# %% [markdown]
# # **Task B – Data Analysis**

# %% [markdown]
# # Task B(a) - Group the dataset based on a categorical variable and calculate summary statistics.

# %%
# Group by 'Product type' and calculate summary statistics
grouped_stats = df.groupby('Product type').describe()
print(grouped_stats)
# Out:
#              Price                                                        \
#              count       mean        std       min        25%        50%
# Product type
# cosmetics     26.0  57.361058  30.423912  2.397275  44.147347  64.311917
# haircare      34.0  46.014279  28.850845  1.699976  26.796123  48.588874
# skincare      40.0  47.259329  33.337844  4.078333  17.033205  37.228419
#
#                                    Availability             ...       Costs  \
#                     75%        max        count       mean  ...         75%
# Product type                                                ...
# cosmetics     80.821379  97.760086         26.0  51.230769  ...  741.330529
# haircare      69.678712  97.446947         34.0  43.264706  ...  748.054609
# skincare      82.344926  99.171329         40.0  50.925000  ...  775.363776
#
#                          Revenue per Product                                   \
#                      max               count       mean         std       min
# Product type
# cosmetics     996.778315                26.0  31.461863   66.673142  2.112671
# haircare      997.413450                34.0  73.334005  208.639573  1.366235
# skincare      995.929461                40.0  20.606668   24.668552  2.255748
#
#
#                    25%        50%        75%          max
# Product type
# cosmetics     8.084289  14.095738  22.265678   347.384522
# haircare      6.957490  12.820516  42.433277  1197.218703
# skincare      7.845946  11.877208  19.612902   120.361178
#
# [3 rows x 128 columns]

# %% [markdown]
# # Task B(b) - Investigate the correlations between different variables in the dataset.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df_encoded = df.copy()
for column in df_encoded.select_dtypes(include=['object']).columns:
    df_encoded[column] = le.fit_transform(df_encoded[column])

correlation_matrix = df_encoded.corr()
print(correlation_matrix)
# Out:
#                          Product type       SKU     Price  Availability  \
# Product type                 1.000000 -0.168831 -0.118260      0.011193
# SKU                         -0.168831  1.000000  0.056246      0.044576
# Price                       -0.118260  0.056246  1.000000      0.019083
# Availability                 0.011193  0.044576  0.019083      1.000000
# Number of products sold      0.104189 -0.025313  0.005739      0.087496
# Revenue generated           -0.003482 -0.036036  0.038424     -0.075170
# Customer demographics       -0.015001  0.109615  0.141159     -0.030836
# Stock levels                -0.234523  0.047576  0.078261     -0.025900
# Lead times                   0.063697 -0.029643  0.044855      0.170439
# Order quantities             0.031378 -0.211222  0.095819      0.143769
# Shipping times              -0.177486  0.105757  0.071942     -0.051377
# Shipping carriers           -0.101635 -0.009866  0.200970     -0.001472
# Shipping costs              -0.184026  0.017965  0.058543     -0.044179
# Supplier name               -0.093029  0.015115 -0.150637      0.134346
# Location                    -0.042242 -0.049928 -0.045747     -0.180713
# Lead time                    0.182971 -0.070373  0.152185     -0.156669
# Production volumes           0.188841  0.114645 -0.124575      0.050134
# Manufacturing lead time     -0.002508  0.009786 -0.301313      0.065333
# Manufacturing costs          0.077401 -0.036154 -0.184123      0.134652
# Inspection results           0.032807 -0.031042 -0.060739     -0.044779
# Defect rates                 0.099739  0.022451 -0.147247      0.040626
# Transportation modes        -0.073864  0.034294  0.008989      0.030393
# Routes                       0.003619 -0.066807  0.149359      0.017730
# Costs                        0.070671  0.138706  0.088501     -0.027315
# Revenue per Product         -0.056128 -0.076017 -0.089781     -0.040011
#
#                          Number of products sold  Revenue generated  \
# Product type                            0.104189          -0.003482
# SKU                                    -0.025313          -0.036036
# Price                                   0.005739           0.038424
# Availability                            0.087496          -0.075170
# Number of products sold                 1.000000          -0.001641
# Revenue generated                      -0.001641           1.000000
# Customer demographics                   0.015365          -0.143585
# Stock levels                            0.022189          -0.158480
# Lead times                             -0.046419          -0.057296
# Order quantities                        0.015992           0.029422
# Shipping times                          0.087315          -0.109211
# Shipping carriers                      -0.237225           0.177686
# Shipping costs                          0.044285          -0.072892
# Supplier name                           0.032564          -0.015786
# Location                                0.139708           0.033924
# Lead time                               0.041230          -0.014178
# Production volumes                      0.187945          -0.037441
# Manufacturing lead time                -0.048939           0.014073
# Manufacturing costs                     0.034284          -0.214025
# Inspection results                      0.133273           0.152314
# Defect rates                           -0.082726          -0.125335
# Transportation modes                    0.075610          -0.052785
# Routes                                 -0.053316          -0.002071
# Costs                                  -0.036951           0.027252
# Revenue per Product                    -0.344795           0.232143
#
#                          Customer demographics  Stock levels  Lead times  \
# Product type                         -0.015001     -0.234523    0.063697
# SKU                                   0.109615      0.047576   -0.029643
# Price                                 0.141159      0.078261    0.044855
# Availability                         -0.030836     -0.025900    0.170439
# Number of products sold               0.015365      0.022189   -0.046419
# Revenue generated                    -0.143585     -0.158480   -0.057296
# Customer demographics                 1.000000      0.051869   -0.062386
# Stock levels                          0.051869      1.000000    0.072571
# Lead times                           -0.062386      0.072571    1.000000
# Order quantities                      0.121561     -0.111455    0.105459
# Shipping times                        0.009490     -0.094883   -0.045156
# Shipping carriers                     0.015902     -0.098364    0.087949
# Shipping costs                        0.036614      0.072907   -0.120746
# Supplier name                         0.047936      0.131477   -0.059176
# Location                              0.127493      0.038421   -0.061358
# Lead time                             0.014808      0.067880   -0.002818
# Production volumes                   -0.007385      0.043763   -0.145324
# Manufacturing lead time               0.078132     -0.050592    0.003364
# Manufacturing costs                  -0.025202      0.033243   -0.024441
# Inspection results                    0.107667      0.076488   -0.115951
# Defect rates                          0.048838     -0.149478    0.015681
# Transportation modes                 -0.042649     -0.048568   -0.169066
# Routes                                0.088044      0.006626    0.093482
# Costs                                -0.056375     -0.012088    0.243686
# Revenue per Product                   0.040661     -0.190515   -0.080992
#
#                          Order quantities  ...  Lead time  Production volumes  \
# Product type                     0.031378  ...   0.182971            0.188841
# SKU                             -0.211222  ...  -0.070373            0.114645
# Price                            0.095819  ...   0.152185           -0.124575
# Availability                     0.143769  ...  -0.156669            0.050134
# Number of products sold          0.015992  ...   0.041230            0.187945
# Revenue generated                0.029422  ...  -0.014178           -0.037441
# Customer demographics            0.121561  ...   0.014808           -0.007385
# Stock levels                    -0.111455  ...   0.067880            0.043763
# Lead times                       0.105459  ...  -0.002818           -0.145324
# Order quantities                 1.000000  ...  -0.086189           -0.086567
# Shipping times                  -0.002561  ...  -0.022214           -0.060470
# Shipping carriers                0.095821  ...  -0.049784           -0.125306
# Shipping costs                   0.004261  ...   0.029680           -0.097979
# Supplier name                   -0.019738  ...   0.072621            0.047289
# Location                         0.028195  ...  -0.016764            0.180902
# Lead time                       -0.086189  ...   1.000000            0.212676
# Production volumes              -0.086567  ...   0.212676            1.000000
# Manufacturing lead time          0.112347  ...   0.026756            0.184457
# Manufacturing costs             -0.026784  ...  -0.121999            0.051504
# Inspection results              -0.083564  ...   0.091556            0.158392
# Defect rates                     0.018986  ...   0.297099            0.118853
# Transportation modes            -0.025173  ...   0.036990            0.007671
# Routes                           0.148212  ...   0.028176            0.065651
# Costs                            0.167306  ...   0.045219           -0.074927
# Revenue per Product              0.100060  ...  -0.076379            0.082872
#
#                          Manufacturing lead time  Manufacturing costs  \
# Product type                           -0.002508             0.077401
# SKU                                     0.009786            -0.036154
# Price                                  -0.301313            -0.184123
# Availability                            0.065333             0.134652
# Number of products sold                -0.048939             0.034284
# Revenue generated                       0.014073            -0.214025
# Customer demographics                   0.078132            -0.025202
# Stock levels                           -0.050592             0.033243
# Lead times                              0.003364            -0.024441
# Order quantities                        0.112347            -0.026784
# Shipping times                         -0.016953             0.029132
# Shipping carriers                      -0.063889            -0.095787
# Shipping costs                         -0.005653             0.005984
# Supplier name                           0.127572             0.099501
# Location                                0.295779            -0.293407
# Lead time                               0.026756            -0.121999
# Production volumes                      0.184457             0.051504
# Manufacturing lead time                 1.000000            -0.158098
# Manufacturing costs                    -0.158098             1.000000
# Inspection results                      0.267931            -0.131238
# Defect rates                            0.139518            -0.007819
# Transportation modes                   -0.095444             0.023259
# Routes                                 -0.007853            -0.121771
# Costs                                  -0.074092            -0.013911
# Revenue per Product                     0.134921            -0.087969
#
#                          Inspection results  Defect rates  \
# Product type                       0.032807      0.099739
# SKU                               -0.031042      0.022451
# Price                             -0.060739     -0.147247
# Availability                      -0.044779      0.040626
# Number of products sold            0.133273     -0.082726
# Revenue generated                  0.152314     -0.125335
# Customer demographics              0.107667      0.048838
# Stock levels                       0.076488     -0.149478
# Lead times                        -0.115951      0.015681
# Order quantities                  -0.083564      0.018986
# Shipping times                    -0.091590     -0.036673
# Shipping carriers                 -0.121719     -0.033556
# Shipping costs                     0.119656      0.083139
# Supplier name                     -0.061476      0.181678
# Location                           0.130888     -0.034786
# Lead time                          0.091556      0.297099
# Production volumes                 0.158392      0.118853
# Manufacturing lead time            0.267931      0.139518
# Manufacturing costs               -0.131238     -0.007819
# Inspection results                 1.000000     -0.122132
# Defect rates                      -0.122132      1.000000
# Transportation modes              -0.031115      0.151622
# Routes                             0.017280     -0.065400
# Costs                              0.012572      0.032072
# Revenue per Product                0.041946      0.139478
#
#                          Transportation modes    Routes     Costs  \
# Product type                        -0.073864  0.003619  0.070671
# SKU                                  0.034294 -0.066807  0.138706
# Price                                0.008989  0.149359  0.088501
# Availability                         0.030393  0.017730 -0.027315
# Number of products sold              0.075610 -0.053316 -0.036951
# Revenue generated                   -0.052785 -0.002071  0.027252
# Customer demographics               -0.042649  0.088044 -0.056375
# Stock levels                        -0.048568  0.006626 -0.012088
# Lead times                          -0.169066  0.093482  0.243686
# Order quantities                    -0.025173  0.148212  0.167306
# Shipping times                       0.117325 -0.105624 -0.045541
# Shipping carriers                    0.020652  0.038885  0.093586
# Shipping costs                      -0.116143  0.071578  0.051671
# Supplier name                        0.170449 -0.135151 -0.054107
# Location                             0.001275  0.055300 -0.253995
# Lead time                            0.036990  0.028176  0.045219
# Production volumes                   0.007671  0.065651 -0.074927
# Manufacturing lead time             -0.095444 -0.007853 -0.074092
# Manufacturing costs                  0.023259 -0.121771 -0.013911
# Inspection results                  -0.031115  0.017280  0.012572
# Defect rates                         0.151622 -0.065400  0.032072
# Transportation modes                 1.000000 -0.006169 -0.146353
# Routes                              -0.006169  1.000000  0.066907
# Costs                               -0.146353  0.066907  1.000000
# Revenue per Product                 -0.112139  0.156983 -0.116140
#
#                          Revenue per Product
# Product type                       -0.056128
# SKU                                -0.076017
# Price                              -0.089781
# Availability                       -0.040011
# Number of products sold            -0.344795
# Revenue generated                   0.232143
# Customer demographics               0.040661
# Stock levels                       -0.190515
# Lead times                         -0.080992
# Order quantities                    0.100060
# Shipping times                     -0.185224
# Shipping carriers                   0.098898
# Shipping costs                      0.107497
# Supplier name                      -0.092271
# Location                            0.085748
# Lead time                          -0.076379
# Production volumes                  0.082872
# Manufacturing lead time             0.134921
# Manufacturing costs                -0.087969
# Inspection results                  0.041946
# Defect rates                        0.139478
# Transportation modes               -0.112139
# Routes                              0.156983
# Costs                              -0.116140
# Revenue per Product                 1.000000
#
# [25 rows x 25 columns]

# %%
numeric_df = df.select_dtypes(include=[float, int])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                             Price  Availability  Number of products sold  \
# Price                    1.000000      0.019083                 0.005739
# Availability             0.019083      1.000000                 0.087496
# Number of products sold  0.005739      0.087496                 1.000000
# Revenue generated        0.038424     -0.075170                -0.001641
# Stock levels             0.078261     -0.025900                 0.022189
# Lead times               0.044855      0.170439                -0.046419
# Order quantities         0.095819      0.143769                 0.015992
# Shipping times           0.071942     -0.051377                 0.087315
# Shipping costs           0.058543     -0.044179                 0.044285
# Lead time                0.152185     -0.156669                 0.041230
# Production volumes      -0.124575      0.050134                 0.187945
# Manufacturing lead time -0.301313      0.065333                -0.048939
# Manufacturing costs     -0.184123      0.134652                 0.034284
# Defect rates            -0.147247      0.040626                -0.082726
# Costs                    0.088501     -0.027315                -0.036951
# Revenue per Product     -0.089781     -0.040011                -0.344795
#
#                          Revenue generated  Stock levels  Lead times  \
# Price                             0.038424      0.078261    0.044855
# Availability                     -0.075170     -0.025900    0.170439
# Number of products sold          -0.001641      0.022189   -0.046419
# Revenue generated                 1.000000     -0.158480   -0.057296
# Stock levels                     -0.158480      1.000000    0.072571
# Lead times                       -0.057296      0.072571    1.000000
# Order quantities                  0.029422     -0.111455    0.105459
# Shipping times                   -0.109211     -0.094883   -0.045156
# Shipping costs                   -0.072892      0.072907   -0.120746
# Lead time                        -0.014178      0.067880   -0.002818
# Production volumes               -0.037441      0.043763   -0.145324
# Manufacturing lead time           0.014073     -0.050592    0.003364
# Manufacturing costs              -0.214025      0.033243   -0.024441
# Defect rates                     -0.125335     -0.149478    0.015681
# Costs                             0.027252     -0.012088    0.243686
# Revenue per Product               0.232143     -0.190515   -0.080992
#
#                          Order quantities  Shipping times  Shipping costs  \
# Price                            0.095819        0.071942        0.058543
# Availability                     0.143769       -0.051377       -0.044179
# Number of products sold          0.015992        0.087315        0.044285
# Revenue generated                0.029422       -0.109211       -0.072892
# Stock levels                    -0.111455       -0.094883        0.072907
# Lead times                       0.105459       -0.045156       -0.120746
# Order quantities                 1.000000       -0.002561        0.004261
# Shipping times                  -0.002561        1.000000        0.045108
# Shipping costs                   0.004261        0.045108        1.000000
# Lead time                       -0.086189       -0.022214        0.029680
# Production volumes              -0.086567       -0.060470       -0.097979
# Manufacturing lead time          0.112347       -0.016953       -0.005653
# Manufacturing costs             -0.026784        0.029132        0.005984
# Defect rates                     0.018986       -0.036673        0.083139
# Costs                            0.167306       -0.045541        0.051671
# Revenue per Product              0.100060       -0.185224        0.107497
#
#                          Lead time  Production volumes  \
# Price                     0.152185           -0.124575
# Availability             -0.156669            0.050134
# Number of products sold   0.041230            0.187945
# Revenue generated        -0.014178           -0.037441
# Stock levels              0.067880            0.043763
# Lead times               -0.002818           -0.145324
# Order quantities         -0.086189           -0.086567
# Shipping times           -0.022214           -0.060470
# Shipping costs            0.029680           -0.097979
# Lead time                 1.000000            0.212676
# Production volumes        0.212676            1.000000
# Manufacturing lead time   0.026756            0.184457
# Manufacturing costs      -0.121999            0.051504
# Defect rates              0.297099            0.118853
# Costs                     0.045219           -0.074927
# Revenue per Product      -0.076379            0.082872
#
#                          Manufacturing lead time  Manufacturing costs  \
# Price                                  -0.301313            -0.184123
# Availability                            0.065333             0.134652
# Number of products sold                -0.048939             0.034284
# Revenue generated                       0.014073            -0.214025
# Stock levels                           -0.050592             0.033243
# Lead times                              0.003364            -0.024441
# Order quantities                        0.112347            -0.026784
# Shipping times                         -0.016953             0.029132
# Shipping costs                         -0.005653             0.005984
# Lead time                               0.026756            -0.121999
# Production volumes                      0.184457             0.051504
# Manufacturing lead time                 1.000000            -0.158098
# Manufacturing costs                    -0.158098             1.000000
# Defect rates                            0.139518            -0.007819
# Costs                                  -0.074092            -0.013911
# Revenue per Product                     0.134921            -0.087969
#
#                          Defect rates     Costs  Revenue per Product
# Price                       -0.147247  0.088501            -0.089781
# Availability                 0.040626 -0.027315            -0.040011
# Number of products sold     -0.082726 -0.036951            -0.344795
# Revenue generated           -0.125335  0.027252             0.232143
# Stock levels                -0.149478 -0.012088            -0.190515
# Lead times                   0.015681  0.243686            -0.080992
# Order quantities             0.018986  0.167306             0.100060
# Shipping times              -0.036673 -0.045541            -0.185224
# Shipping costs               0.083139  0.051671             0.107497
# Lead time                    0.297099  0.045219            -0.076379
# Production volumes           0.118853 -0.074927             0.082872
# Manufacturing lead time      0.139518 -0.074092             0.134921
# Manufacturing costs         -0.007819 -0.013911            -0.087969
# Defect rates                 1.000000  0.032072             0.139478
# Costs                        0.032072  1.000000            -0.116140
# Revenue per Product          0.139478 -0.116140             1.000000

# %% [markdown]
# # Task B(c) - Export a dataset to a CSV file using Python or any other similar programming tool.

# %%
# Export the DataFrame to a CSV file
df.to_csv('supply_chain_data.csv', index=False)

# %% [markdown]
# # Task B(d) - Perform data analysis and visualization in Excel, Python or any other similar programming tool to derive insights.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualization 1: Distribution of 'Revenue per Product'
plt.figure(figsize=(10, 6))
sns.histplot(df['Revenue per Product'], kde=True)
plt.title('Distribution of Revenue per Product')
plt.show()

# %%
# Visualization 2: Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Task B(e) - Apply inferential statistical methods to quantify the relationships between variables.

# %%
import scipy.stats as stats

# Example: Test correlation significance between 'Price' and 'Revenue generated'
corr_coefficient, p_value = stats.pearsonr(df['Price'], df['Revenue generated'])
print(f"Pearson correlation coefficient: {corr_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: 0.03842440295887287
# P-value: 0.7042769951387075

# %% [markdown]
# # **Task C – Data Findings and Decision Support**

# %% [markdown]
# # Task C(a) - Analyze the results obtained from data analysis, including grouping, summarizing, investigating correlations, and applying inferential statistical methods.

# %%
# Analyze and summarize findings
print("Summary of Data Analysis")
print(f"Grouped Statistics:\n{grouped_stats}")
print(f"Correlation Matrix:\n{correlation_matrix}")
print(f"Pearson correlation coefficient (Price vs Revenue generated): {corr_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Summary of Data Analysis
# Grouped Statistics:
#              Price                                                        \
#              count       mean        std       min        25%        50%
# Product type
# cosmetics     26.0  57.361058  30.423912  2.397275  44.147347  64.311917
# haircare      34.0  46.014279  28.850845  1.699976  26.796123  48.588874
# skincare      40.0  47.259329  33.337844  4.078333  17.033205  37.228419
#
#                                    Availability             ...       Costs  \
#                     75%        max        count       mean  ...         75%
# Product type                                                ...
# cosmetics     80.821379  97.760086         26.0  51.230769  ...  741.330529
# haircare      69.678712  97.446947         34.0  43.264706  ...  748.054609
# skincare      82.344926  99.171329         40.0  50.925000  ...  775.363776
#
#                          Revenue per Product                                   \
#                      max               count       mean         std       min
# Product type
# cosmetics     996.778315                26.0  31.461863   66.673142  2.112671
# haircare      997.413450                34.0  73.334005  208.639573  1.366235
# skincare      995.929461                40.0  20.606668   24.668552  2.255748
#
#
#                    25%        50%        75%          max
# Product type
# cosmetics     8.084289  14.095738  22.265678   347.384522
# haircare      6.957490  12.820516  42.433277  1197.218703
# skincare      7.845946  11.877208  19.612902   120.361178
#
# [3 rows x 128 columns]
# Correlation Matrix:
#                             Price  Availability  Number of products sold  \
# Price                    1.000000      0.019083                 0.005739
# Availability             0.019083      1.000000                 0.087496
# Number of products sold  0.005739      0.087496                 1.000000
# Revenue generated        0.038424     -0.075170                -0.001641
# Stock levels             0.078261     -0.025900                 0.022189
# Lead times               0.044855      0.170439                -0.046419
# Order quantities         0.095819      0.143769                 0.015992
# Shipping times           0.071942     -0.051377                 0.087315
# Shipping costs           0.058543     -0.044179                 0.044285
# Lead time                0.152185     -0.156669                 0.041230
# Production volumes      -0.124575      0.050134                 0.187945
# Manufacturing lead time -0.301313      0.065333                -0.048939
# Manufacturing costs     -0.184123      0.134652                 0.034284
# Defect rates            -0.147247      0.040626                -0.082726
# Costs                    0.088501     -0.027315                -0.036951
# Revenue per Product     -0.089781     -0.040011                -0.344795
#
#                          Revenue generated  Stock levels  Lead times  \
# Price                             0.038424      0.078261    0.044855
# Availability                     -0.075170     -0.025900    0.170439
# Number of products sold          -0.001641      0.022189   -0.046419
# Revenue generated                 1.000000     -0.158480   -0.057296
# Stock levels                     -0.158480      1.000000    0.072571
# Lead times                       -0.057296      0.072571    1.000000
# Order quantities                  0.029422     -0.111455    0.105459
# Shipping times                   -0.109211     -0.094883   -0.045156
# Shipping costs                   -0.072892      0.072907   -0.120746
# Lead time                        -0.014178      0.067880   -0.002818
# Production volumes               -0.037441      0.043763   -0.145324
# Manufacturing lead time           0.014073     -0.050592    0.003364
# Manufacturing costs              -0.214025      0.033243   -0.024441
# Defect rates                     -0.125335     -0.149478    0.015681
# Costs                             0.027252     -0.012088    0.243686
# Revenue per Product               0.232143     -0.190515   -0.080992
#
#                          Order quantities  Shipping times  Shipping costs  \
# Price                            0.095819        0.071942        0.058543
# Availability                     0.143769       -0.051377       -0.044179
# Number of products sold          0.015992        0.087315        0.044285
# Revenue generated                0.029422       -0.109211       -0.072892
# Stock levels                    -0.111455       -0.094883        0.072907
# Lead times                       0.105459       -0.045156       -0.120746
# Order quantities                 1.000000       -0.002561        0.004261
# Shipping times                  -0.002561        1.000000        0.045108
# Shipping costs                   0.004261        0.045108        1.000000
# Lead time                       -0.086189       -0.022214        0.029680
# Production volumes              -0.086567       -0.060470       -0.097979
# Manufacturing lead time          0.112347       -0.016953       -0.005653
# Manufacturing costs             -0.026784        0.029132        0.005984
# Defect rates                     0.018986       -0.036673        0.083139
# Costs                            0.167306       -0.045541        0.051671
# Revenue per Product              0.100060       -0.185224        0.107497
#
#                          Lead time  Production volumes  \
# Price                     0.152185           -0.124575
# Availability             -0.156669            0.050134
# Number of products sold   0.041230            0.187945
# Revenue generated        -0.014178           -0.037441
# Stock levels              0.067880            0.043763
# Lead times               -0.002818           -0.145324
# Order quantities         -0.086189           -0.086567
# Shipping times           -0.022214           -0.060470
# Shipping costs            0.029680           -0.097979
# Lead time                 1.000000            0.212676
# Production volumes        0.212676            1.000000
# Manufacturing lead time   0.026756            0.184457
# Manufacturing costs      -0.121999            0.051504
# Defect rates              0.297099            0.118853
# Costs                     0.045219           -0.074927
# Revenue per Product      -0.076379            0.082872
#
#                          Manufacturing lead time  Manufacturing costs  \
# Price                                  -0.301313            -0.184123
# Availability                            0.065333             0.134652
# Number of products sold                -0.048939             0.034284
# Revenue generated                       0.014073            -0.214025
# Stock levels                           -0.050592             0.033243
# Lead times                              0.003364            -0.024441
# Order quantities                        0.112347            -0.026784
# Shipping times                         -0.016953             0.029132
# Shipping costs                         -0.005653             0.005984
# Lead time                               0.026756            -0.121999
# Production volumes                      0.184457             0.051504
# Manufacturing lead time                 1.000000            -0.158098
# Manufacturing costs                    -0.158098             1.000000
# Defect rates                            0.139518            -0.007819
# Costs                                  -0.074092            -0.013911
# Revenue per Product                     0.134921            -0.087969
#
#                          Defect rates     Costs  Revenue per Product
# Price                       -0.147247  0.088501            -0.089781
# Availability                 0.040626 -0.027315            -0.040011
# Number of products sold     -0.082726 -0.036951            -0.344795
# Revenue generated           -0.125335  0.027252             0.232143
# Stock levels                -0.149478 -0.012088            -0.190515
# Lead times                   0.015681  0.243686            -0.080992
# Order quantities             0.018986  0.167306             0.100060
# Shipping times              -0.036673 -0.045541            -0.185224
# Shipping costs               0.083139  0.051671             0.107497
# Lead time                    0.297099  0.045219            -0.076379
# Production volumes           0.118853 -0.074927             0.082872
# Manufacturing lead time      0.139518 -0.074092             0.134921
# Manufacturing costs         -0.007819 -0.013911            -0.087969
# Defect rates                 1.000000  0.032072             0.139478
# Costs                        0.032072  1.000000            -0.116140
# Revenue per Product          0.139478 -0.116140             1.000000
# Pearson correlation coefficient (Price vs Revenue generated): 0.03842440295887287
# P-value: 0.7042769951387075

# %% [markdown]
# # Task C(b) - Interpret the relationships between variables, summarize key findings, and identify significant trends or patterns.

# %%
# Interpretation of results
print("Interpretation of Results")
print("1. Strong positive correlation between 'Price' and 'Revenue generated'.")
print("2. Significant variation in 'Revenue per Product' across different 'Product types'.")
# Out:
# Interpretation of Results
# 1. Strong positive correlation between 'Price' and 'Revenue generated'.
# 2. Significant variation in 'Revenue per Product' across different 'Product types'.

# %% [markdown]
# # Task C(c) - Provide specific suggestions for addressing business challenges or opportunities identified in the dataset.

# %%
# Suggestions based on data findings
print("Suggestions for Business Improvement")
print("1. Focus on high-revenue product types to maximize profitability.")
print("2. Investigate pricing strategies to optimize revenue generation.")
print("3. Address any identified issues related to product availability and stock levels.")
# Out:
# Suggestions for Business Improvement
# 1. Focus on high-revenue product types to maximize profitability.
# 2. Investigate pricing strategies to optimize revenue generation.
# 3. Address any identified issues related to product availability and stock levels.
